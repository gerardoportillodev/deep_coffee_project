# %% [markdown]
# # Stage 2: Specialized CNN
# Notebook scaffold for developing and comparing CNN architectures.

# %% [markdown]
# ## Sections
# 1) Setup
# 2) Model design
# 3) Training
# 4) Evaluation
# 5) Comparison vs Stage 1
