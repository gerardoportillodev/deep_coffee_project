# %% [markdown]
# # Stage 3: Transfer Learning
# Notebook scaffold for pretrained backbones and fine-tuned heads.

# %% [markdown]
# ## Sections
# 1) Backbone selection
# 2) Freezing strategy
# 3) Training
# 4) Evaluation
# 5) Ablations
